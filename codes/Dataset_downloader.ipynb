# %%
! pip freeze > requirements.txt

# %%
import fiftyone as fo
import fiftyone.zoo as foz
import os
import shutil

# %% [markdown]
# Some utility functions to sort datatset images

# %%
# make directory with 'dir_name'
def make_dir(path, dir_name):
    if not path.endswith("/"):
        path+="/"
    if not (os.path.isdir(path+dir_name)):
        os.makedirs(path+dir_name)

# %%
# move all jpg images from 'src' to 'dest'
def move_imgs(src, dest):
    if not src.endswith("/"):
        src+="/"
    if not dest.endswith("/"):
        dest+="/"
    img_files = [x for x in os.listdir(src) if x.endswith(".jpg")]
    for img in img_files:
        shutil.move(src+img, dest+img)

# %% [markdown]
# Initializing variables

# %%
class_names = ['Airplane', 'Ambulance', 'Bicycle', 'Bus', 'Car', 'Fire hydrant', 'Helicopter', 
               'Motorcycle', 'Parking meter', 'Stop sign', 'Taxi', 'Traffic sign', 'Truck']

# Change below directories to those of yours
train_dir = "C:/Users/Everage/fiftyone/open-images-v6/train/data" # default path for downloaded images
validation_dir = "C:/Users/Everage/fiftyone/open-images-v6/validation/data" 
test_dir = "C:/Users/Everage/fiftyone/open-images-v6/test/data"

# %% [markdown]
# Downloading Open Images V6 dataset

# %%
dataset = foz.load_zoo_dataset(
    "open-images-v6",
    split="train", # ['train', 'val', 'test']
    label_types=['classifications'],
    classes=class_names[0],
    max_samples=1000,
    dataset_name="Open_images_train"
)
make_dir(train_dir, class_names[0])
move_imgs(train_dir, train_dir+"/"+class_names[0])
# Out:
# Downloading split 'train' to 'C:\Users\Everage\fiftyone\open-images-v6\train' if necessary
# Downloading 1000 images
#  100% |█████████████████| 1000/1000 [1.1m elapsed, 0s remaining, 8.7 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'train'
#  100% |███████████████| 1000/1000 [2.7s elapsed, 0s remaining, 493.4 samples/s]
# Dataset 'Open_images_train' created

# %%
for name in class_names[1:]:
    make_dir(train_dir, name)
    sub_set = foz.load_zoo_dataset(
        "open-images-v6",
        split="train", # ['train', 'validation', 'test']
        label_types=['classifications'],
        classes=name,
        max_samples=1000,
        dataset_name="Open_images_train_sub"
    )
    move_imgs(train_dir, train_dir+f"/{name}")
    merged = dataset.merge_samples(sub_set)
    sub_set.delete()
    print(f"Downloaded Class: {name}")
    print()
# Out:
# Downloading split 'validation' to 'C:\Users\Everage\fiftyone\open-images-v6\validation' if necessary
# Only found 33 (<500) samples matching your requirements
# Necessary images already downloaded
# Existing download of split 'validation' is sufficient
# Loading existing dataset 'Open_images_validation_sub'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use
# Downloaded Class: Ambulance
#
# Downloading split 'validation' to 'C:\Users\Everage\fiftyone\open-images-v6\validation' if necessary
# Only found 381 (<500) samples matching your requirements
# Downloading 381 images
#  100% |███████████████████| 381/381 [24.1s elapsed, 0s remaining, 9.9 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'validation'
#  100% |█████████████████| 381/381 [952.7ms elapsed, 0s remaining, 399.9 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Bicycle
#
# Downloading split 'validation' to 'C:\Users\Everage\fiftyone\open-images-v6\validation' if necessary
# Only found 131 (<500) samples matching your requirements
# Downloading 131 images
#  100% |███████████████████| 131/131 [10.5s elapsed, 0s remaining, 14.9 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'validation'
#  100% |█████████████████| 131/131 [267.4ms elapsed, 0s remaining, 489.8 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Bus
#
# Downloading split 'validation' to 'C:\Users\Everage\fiftyone\open-images-v6\validation' if necessary
# Downloading 500 images
#  100% |███████████████████| 500/500 [28.2s elapsed, 0s remaining, 11.1 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'validation'
#  100% |█████████████████| 500/500 [916.2ms elapsed, 0s remaining, 545.8 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Car
#
# Downloading split 'validation' to 'C:\Users\Everage\fiftyone\open-images-v6\validation' if necessary
# Only found 25 (<500) samples matching your requirements
# Downloading 25 images
#  100% |█████████████████████| 25/25 [3.9s elapsed, 0s remaining, 9.6 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████████| 25/25 [66.3ms elapsed, 0s remaining, 376.8 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Fire hydrant
#
# Downloading split 'validation' to 'C:\Users\Everage\fiftyone\open-images-v6\validation' if necessary
# Only found 166 (<500) samples matching your requirements
# Downloading 166 images
#  100% |███████████████████| 166/166 [9.7s elapsed, 0s remaining, 12.2 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'validation'
#  100% |█████████████████| 166/166 [233.3ms elapsed, 0s remaining, 711.6 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Helicopter
#
# Downloading split 'validation' to 'C:\Users\Everage\fiftyone\open-images-v6\validation' if necessary
# Only found 230 (<500) samples matching your requirements
# Downloading 230 images
#  100% |███████████████████| 230/230 [15.6s elapsed, 0s remaining, 10.2 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'validation'
#  100% |█████████████████| 230/230 [542.9ms elapsed, 0s remaining, 423.7 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Motorcycle
#
# Downloading split 'validation' to 'C:\Users\Everage\fiftyone\open-images-v6\validation' if necessary
# Only found 4 (<500) samples matching your requirements
# Downloading 4 images
#  100% |███████████████████████| 4/4 [1.9s elapsed, 0s remaining, 2.1 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'validation'
#  100% |█████████████████████| 4/4 [28.8ms elapsed, 0s remaining, 138.9 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Parking meter
#
# Downloading split 'validation' to 'C:\Users\Everage\fiftyone\open-images-v6\validation' if necessary
# Only found 27 (<500) samples matching your requirements
# Downloading 27 images
#  100% |█████████████████████| 27/27 [3.0s elapsed, 0s remaining, 17.2 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████████| 27/27 [59.7ms elapsed, 0s remaining, 452.5 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Stop sign
#
# Downloading split 'validation' to 'C:\Users\Everage\fiftyone\open-images-v6\validation' if necessary
# Only found 61 (<500) samples matching your requirements
# Downloading 61 images
#  100% |█████████████████████| 61/61 [5.5s elapsed, 0s remaining, 11.4 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████████| 61/61 [127.5ms elapsed, 0s remaining, 484.4 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Taxi
#
# Downloading split 'validation' to 'C:\Users\Everage\fiftyone\open-images-v6\validation' if necessary
# Only found 63 (<500) samples matching your requirements
# Downloading 63 images
#  100% |█████████████████████| 63/63 [6.6s elapsed, 0s remaining, 5.6 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████████| 63/63 [126.5ms elapsed, 0s remaining, 503.3 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Traffic sign
#
# Downloading split 'validation' to 'C:\Users\Everage\fiftyone\open-images-v6\validation' if necessary
# Only found 477 (<500) samples matching your requirements
# Downloading 477 images
#  100% |███████████████████| 477/477 [37.0s elapsed, 0s remaining, 14.6 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'validation'
#  100% |█████████████████| 477/477 [842.0ms elapsed, 0s remaining, 567.6 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Truck

# %%
dataset = foz.load_zoo_dataset(
    "open-images-v6",
    split="test", # ['train', 'val', 'test']
    label_types=['classifications'],
    classes=[class_names[0]],
    max_samples=200,
    dataset_name="Open_images_validation"
)
make_dir(test_dir, class_names[0])
move_imgs(test_dir, test_dir+"/"+class_names[0])
# Out:
# Downloading split 'test' to 'C:\Users\Everage\fiftyone\open-images-v6\test' if necessary
# Downloading 'https://storage.googleapis.com/openimages/2018_04/test/test-images-with-rotation.csv' to 'C:\Users\Everage\fiftyone\open-images-v6\test\metadata\image_ids.csv'
# Downloading 'https://storage.googleapis.com/openimages/v5/class-descriptions-boxable.csv' to 'C:\Users\Everage\fiftyone\open-images-v6\test\metadata\classes.csv'
# Downloading 'https://storage.googleapis.com/openimages/2018_04/bbox_labels_600_hierarchy.json' to 'C:\Users\Everage\AppData\Local\Temp\tmp86_ighuc\metadata\hierarchy.json'
# Downloading 'https://storage.googleapis.com/openimages/v5/test-annotations-human-imagelabels-boxable.csv' to 'C:\Users\Everage\fiftyone\open-images-v6\test\labels\classifications.csv'
# Downloading 200 images
#  100% |███████████████████| 200/200 [12.9s elapsed, 0s remaining, 13.2 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading existing dataset 'Open_images_validation'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use

# %%
for name in class_names[1:]:
    make_dir(test_dir, name)
    sub_set = foz.load_zoo_dataset(
        "open-images-v6",
        split="test", # ['train', 'validation', 'test']
        label_types=['classifications'],
        classes=name,
        max_samples=500,
        dataset_name="Open_images_validation_sub"
    )
    move_imgs(test_dir, test_dir+f"/{name}")
    merged = dataset.merge_samples(sub_set)
    sub_set.delete()
    print(f"Downloaded Class: {name}")
    print()
# Out:
# Downloading split 'test' to 'C:\Users\Everage\fiftyone\open-images-v6\test' if necessary
# Only found 93 (<500) samples matching your requirements
# Downloading 93 images
#  100% |█████████████████████| 93/93 [9.0s elapsed, 0s remaining, 6.8 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'test'
#  100% |███████████████████| 93/93 [199.2ms elapsed, 0s remaining, 467.0 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Ambulance
#
# Downloading split 'test' to 'C:\Users\Everage\fiftyone\open-images-v6\test' if necessary
# Downloading 500 images
#  100% |███████████████████| 500/500 [35.0s elapsed, 0s remaining, 7.5 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'test'
#  100% |█████████████████| 500/500 [1.2s elapsed, 0s remaining, 409.8 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Bicycle
#
# Downloading split 'test' to 'C:\Users\Everage\fiftyone\open-images-v6\test' if necessary
# Only found 424 (<500) samples matching your requirements
# Downloading 424 images
#  100% |███████████████████| 424/424 [40.9s elapsed, 0s remaining, 6.7 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'test'
#  100% |█████████████████| 424/424 [728.1ms elapsed, 0s remaining, 582.3 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Bus
#
# Downloading split 'test' to 'C:\Users\Everage\fiftyone\open-images-v6\test' if necessary
# Downloading 500 images
#  100% |███████████████████| 500/500 [45.6s elapsed, 0s remaining, 1.8 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'test'
#  100% |█████████████████| 500/500 [787.1ms elapsed, 0s remaining, 636.5 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Car
#
# Downloading split 'test' to 'C:\Users\Everage\fiftyone\open-images-v6\test' if necessary
# Only found 105 (<500) samples matching your requirements
# Downloading 105 images
#  100% |███████████████████| 105/105 [29.9s elapsed, 0s remaining, 5.2 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'test'
#  100% |█████████████████| 105/105 [206.6ms elapsed, 0s remaining, 508.3 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Fire hydrant
#
# Downloading split 'test' to 'C:\Users\Everage\fiftyone\open-images-v6\test' if necessary
# Only found 497 (<500) samples matching your requirements
# Downloading 497 images
#  100% |███████████████████| 497/497 [27.3s elapsed, 0s remaining, 13.2 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'test'
#  100% |█████████████████| 497/497 [642.2ms elapsed, 0s remaining, 775.8 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Helicopter
#
# Downloading split 'test' to 'C:\Users\Everage\fiftyone\open-images-v6\test' if necessary
# Downloading 500 images
#  100% |███████████████████| 500/500 [33.3s elapsed, 0s remaining, 9.3 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'test'
#  100% |█████████████████| 500/500 [1.1s elapsed, 0s remaining, 444.0 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Motorcycle
#
# Downloading split 'test' to 'C:\Users\Everage\fiftyone\open-images-v6\test' if necessary
# Only found 6 (<500) samples matching your requirements
# Downloading 6 images
#  100% |███████████████████████| 6/6 [1.8s elapsed, 0s remaining, 3.4 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'test'
#  100% |█████████████████████| 6/6 [30.7ms elapsed, 0s remaining, 195.6 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Parking meter
#
# Downloading split 'test' to 'C:\Users\Everage\fiftyone\open-images-v6\test' if necessary
# Only found 74 (<500) samples matching your requirements
# Downloading 74 images
#  100% |█████████████████████| 74/74 [5.9s elapsed, 0s remaining, 14.8 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'test'
#  100% |███████████████████| 74/74 [119.7ms elapsed, 0s remaining, 618.4 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Stop sign
#
# Downloading split 'test' to 'C:\Users\Everage\fiftyone\open-images-v6\test' if necessary
# Only found 195 (<500) samples matching your requirements
# Downloading 195 images
#  100% |███████████████████| 195/195 [16.1s elapsed, 0s remaining, 4.4 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'test'
#  100% |█████████████████| 195/195 [465.2ms elapsed, 0s remaining, 419.2 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Taxi
#
# Downloading split 'test' to 'C:\Users\Everage\fiftyone\open-images-v6\test' if necessary
# Only found 186 (<500) samples matching your requirements
# Downloading 186 images
#  100% |███████████████████| 186/186 [23.3s elapsed, 0s remaining, 5.2 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'test'
#  100% |█████████████████| 186/186 [307.3ms elapsed, 0s remaining, 605.3 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Traffic sign
#
# Downloading split 'test' to 'C:\Users\Everage\fiftyone\open-images-v6\test' if necessary
# Downloading 500 images
#  100% |███████████████████| 500/500 [37.7s elapsed, 0s remaining, 10.4 files/s]
# Dataset info written to 'C:\Users\Everage\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'test'
#  100% |█████████████████| 500/500 [1.1s elapsed, 0s remaining, 473.3 samples/s]
# Dataset 'Open_images_validation_sub' created
# Downloaded Class: Truck
